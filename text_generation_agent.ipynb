# %%
from content_analyzer import agent_analyzer
content  = agent_analyzer ("https://www.youm7.com/story/2026/5/15/%D9%88%D9%83%D9%8A%D9%84-%D8%A3%D9%88%D9%82%D8%A7%D9%81-%D8%A7%D9%84%D8%B4%D8%B1%D9%82%D9%8A%D8%A9-%D8%AE%D9%84%D8%A7%D9%84-%D8%AE%D8%B7%D8%A8%D8%A9-%D8%A7%D9%84%D8%AC%D9%85%D8%B9%D8%A9-%D8%A7%D9%84%D8%B9%D8%B4%D8%B1-%D8%A7%D9%84%D8%A3%D9%88%D8%A7%D8%A6%D9%84-%D9%85%D9%86-%D8%B0%D9%89/7416808")
# Out:
# ✅ Success! Extracted 10 topics.
# ----------------------------------------
# {
#   "source_language": "Arabic",
#   "content_status": "sufficient",
#   "topics": [
#     {
#       "title": "العشر الأوائل من ذي الحجة",
#       "key_points": [
#         "فضل العشر الأوائل",
#         "أهمية الطاعة في هذه الأيام"
#       ],
#       "insight": "هذه الأيام تعتبر مواسم للطاعات والخيرات",
#       "discussion_angles": [
#         "ما هي الأعمال الصالحة التي يمكن القيام بها في هذه الأيام",
#         "كيف يمكن استغلال هذه الأيام لتقرب إلى الله"
#       ]
#     },
#     {
#       "title": "وكيل أوقاف الشرقية",
#       "key_points": [
#         "دور وكيل الأوقاف في الشرقية",
#         "خطبة الجمعة"
#       ],
#       "insight": "وكيل الأوقاف يلعب دورًا هامًا في الشرقية",
#       "discussion_angles": [
#         "ما هي المسؤوليات الرئيسية لوكيل الأوقاف",
#         "كيف يمكن لوكيل الأوقاف أن يلعب دورًا فعالًا في المجتمع"
#       ]
#     },
#     {
#       "title": "النظافة في الإسلام",
#       "key_points": [
#         "أهمية النظافة في الإسلام",
#         "أنواع النظافة"
#       ],
#       "insight": "النظافة هي قيمة إسلامية أصيلة",
#       "discussion_angles": [
#         "ما هي أنواع النظافة في الإسلام",
#         "كيف يمكن للمسلمين أن يطبقوا النظافة في حياتهم اليومية"
#       ]
#     },
#     {
#       "title": "يوم عرفة",
#       "key_points": [
#         "أهمية يوم عرفة",
#         "فضل يوم عرفة"
#       ],
#       "insight": "يوم عرفة هو يوم تجلي الله بعباده",
#       "discussion_angles": [
#         "ما هي الأعمال الصالحة التي يمكن القيام بها في يوم عرفة",
#         "كيف يمكن استغلال يوم عرفة لتقرب إلى الله"
#       ]
#     },
#     {
#       "title": "الإكثار من ذكر الله",
#       "key_points": [
#         "أهمية ذكر الله",
#         "فوائد ذكر الله"
#       ],
#       "insight": "ذكر الله هو أمر هام في الإسلام",
#       "discussion_angles": [
#         "ما هي فوائد ذكر الله",
#         "كيف يمكن للمسلمين أن يزيدوا من ذكر الله في حياتهم اليومية"
#       ]
#     },
#     {
#       "title": "المتاجرة مع الله",
#       "key_points": [
#         "مفهوم المتاجرة مع الله",
#         "أهمية المتاجرة مع الله"
#       ],
#       "insight": "المتاجرة مع الله هي مفهوم ديني هام",
#       "discussion_angles": [
#         "ما هي أنواع المتاجرة مع الله",
#         "كيف يمكن للمسلمين أن يطبقوا المتاجرة مع الله في حياتهم"
#       ]
#     },
#     {
#       "title": "الاقتداء برسول الله",
#       "key_points": [
#         "أهمية الاقتداء برسول الله",
#         "فوائد الاقتداء برسول الله"
#       ],
#       "insight": "الاقتداء برسول الله هو أمر هام في الإسلام",
#       "discussion_angles": [
#         "ما هي فوائد الاقتداء برسول الله",
#         "كيف يمكن للمسلمين أن يزيدوا من الاقتداء برسول الله في حياتهم اليومية"
#       ]
#     },
#     {
#       "title": "التوبة الصادقة",
#       "key_points": [
#         "أهمية التوبة الصادقة",
#         "فوائد التوبة الصادقة"
#       ],
#       "insight": "التوبة الصادقة هي أمر هام في الإسلام",
#       "discussion_angles": [
#         "ما هي فوائد التوبة الصادقة",
#         "كيف يمكن للمسلمين أن يطبقوا التوبة الصادقة في حياتهم"
#       ]
#     },
#     {
#       "title": "الصلاة والصيام",
#       "key_points": [
#         "أهمية الصلاة والصيام",
#         "فوائد الصلاة والصيام"
#       ],
#       "insight": "الصلاة والصيام هما أمرين هامين في الإسلام",
#       "discussion_angles": [
#         "ما هي فوائد الصلاة والصيام",
#         "كيف يمكن للمسلمين أن يزيدوا من الصلاة والصيام في حياتهم اليومية"
#       ]
#     },
#     {
#       "title": "الصدقة",
#       "key_points": [
#         "أهمية الصدقة",
#         "فوائد الصدقة"
#       ],
#       "insight": "الصدقة هي أمر هام في الإسلام",
#       "discussion_angles": [
#         "ما هي فوائد الصدقة",
#         "كيف يمكن للمسلمين أن يزيدوا من الصدقة في حياتهم اليومية"
#       ]
#     }
#   ]
# }

# %%
from utils import print_script 
print(content)
# Out:
# None

# %%
from chat import textGeneration_chat_chain 
from utils import tojson 
from utils import print_script 
script = textGeneration_chat_chain.invoke({
    "key_points": content,
    "tone": "quite",
    "speech_speed": 1,
    "video_duration": 900
})

# %%
script = tojson(script)
print_script(script)
# Out:
# {
#     "title": "Conversations in Clarity: A Thoughtful Dialogue on Everyday Insights",
#     "estimated_total_words": 900,
#     "total_pages": 1,
#     "pages": [
#         {
#             "page_number": 1,
#             "content": "Host: Welcome back to *Conversations in Clarity*. I’m your host, and today we’re diving into the quiet power of thoughtful reflection—how small, deliberate choices can ripple outward in surprising ways. Joining me is a guest whose work explores the intersection of mindfulness, communication, and everyday resilience. Thanks for being here.\n\nGuest: It’s a pleasure to be here. I’ve always admired how your show balances depth with accessibility—something I think we’ll get into today.\n\nHost: Let’s start with a word you’ve used before: *quite*. Not just as filler, but as a subtle intensifier, a pause, a signal of measured agreement or hesitation. In a world of hyperbole, why does *quite* matter?\n\nGuest: That’s such a sharp observation. *Quite* is often dismissed as weak or redundant, but it’s actually a linguistic safeguard. When we say *quite good* instead of *very good*, we’re inviting nuance. We’re saying, ‘This is good—but not exhaustively, not absolutely.’ It leaves room for complexity, for doubt, for growth.\n\nHost: So it’s less about certainty and more about humility?\n\nGuest: Exactly. Humility in language mirrors humility in thinking. We’re not claiming finality; we’re offering a perspective. And in a time when people are exhausted by absolutism—whether in politics, health, or relationships—that restraint can be deeply restorative.\n\nHost: That makes me wonder: how do we cultivate that kind of measured presence in our daily lives? Not just in speech, but in action?\n\nGuest: One way is through what I call *micro-pauses*. Not long meditations, but tiny interruptions in our automatic responses. A breath before replying in an email. A second of silence before accepting a new commitment. These aren’t delays—they’re recalibrations. They let us ask, *Is this aligned?* rather than *How fast can I do this?*\n\nHost: And yet, modern life seems to reward speed over slowness. How do we protect those micro-pauses without feeling like we’re falling behind?\n\nGuest: It’s a real tension. But consider this: speed without direction is just motion, not progress. A micro-pause isn’t stopping—it’s redirecting energy. Think of a sprinter crouched at the blocks: the stillness before the burst is what makes the acceleration possible.\n\nHost: That’s a beautiful image. So perhaps *quite* isn’t about slowness at all—it’s about intentionality?\n\nGuest: Precisely. Intentionality is the quiet engine of meaningful change. Not grand gestures, but consistent, small acts of alignment. One thoughtful sentence. One honest pause. One *quite* that says, *I’m listening*.\n\nHost: Thank you for that reflection. As we wrap up, what’s one *quite* you’d like to leave our listeners with?\n\nGuest: That *quite* is never just a word. It’s an invitation—to listen more deeply, to speak more carefully, and to live more deliberately. Thank you."
#         }
#     ]
# }

# %%
from audio import text_to_speech
#  Munsit test - saudii (male)
result = await text_to_speech(
    text=script,
    provider="gtts",
    language="ar",
    dialect="fusha",
    gender="male",
    style="natural",
    speed=1.0
)

print("="*50)
print("📊 اختبار Munsit (سعودي - رجل)")
print("="*50)
print(f"✅ Success: {result.get('success')}")
print(f"🎙️ Provider: {result.get('provider')}")
print(f"🗣️ Voice: {result.get('voice')}")
print(f"⏱️ Duration: {result.get('duration', 0):.2f} seconds")
print(f"🔗 Audio URL: {result.get('audio_url')}")
print("="*50)

if result.get('audio_url'):
    import requests
    from IPython.display import Audio, display
    response = requests.get(result['audio_url'])
    display(Audio(response.content))
# Out:
# ==================================================
# Generating speech...
#    Text: مرحباً...
#    Language: ar | Provider: gtts
#    Dialect: fusha | Gender: male | Style: professional | Speed: 1.0
# ==================================================
# Using gTTS
# ==================================================
# 📊 اختبار Munsit (سعودي - رجل)
# ==================================================
# ✅ Success: True
# 🎙️ Provider: gtts
# 🗣️ Voice: Arabic (Fusha) (gTTS)
# ⏱️ Duration: 1.15 seconds
# 🔗 Audio URL: https://res.cloudinary.com/duxc6oeju/video/upload/v1778851603/podcast_audio/uqmbtyo34b8n5pftpt1q.mp3
# ==================================================
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
script = tojson(script)
print_script(script)
# Out:
# 1
# Page 1:
# Host: مرحباً بكم في هذا اللقاء الخاص الذي يتناول أداء نادي تشيلسي في الدوري الإنجليزي الممتاز، بعد أحدث مواجهاته الصعبة أمام نوتنجهام فورست التي انتهت بخسارة مُرّة بنتيجة 3-1. معنا اليوم ضيف خبير في شؤون الكرة الإنجليزية، لنتناول الأسباب، التداعيات، والمسارات الممكنة لاستعادة الثقة. مرحباً بك!
#
# Guest: شكرًا لك، سعيد بالمشاركة.
#
# Host: دعنا نبدأ من الخسارة نفسها: كيف تفسّر تراجع تشيلسي إلى هذا الحد، خاصةً بعد أن استقبل هدفًا مبكرًا عقّد المهمة فور انطلاق المباراة؟
#
# Guest: بالفعل، الهدف المبكر لنوتنجهام فورست كان له تأثير نفسي كبير على لاعبي تشيلسي، إذ أفقد الفريق تركيزه ودفعه إلى اللعب في ملعب الخصم منذ الدقائق الأولى. لكن الأهم من ذلك أن هذه الخسارة ليست منعزلة؛ بل هي تكرار لسلسلة من الأداءات غير المستقرة، ما يشير إلى أزمة هيكلية، لا مجرد تذبذب مؤقت. الأداء غير المستقر قد يؤدي إلى فقدان مركز مؤهل لدوري أبطال أوروبا، وهو ما يُقلق الجماهير والمسؤولين على حد سواء.
#
# Host: وخلال تصريحاته بعد المباراة، حمّل جواو بيدرو اللاعبين المسؤولية، ودعا إلى مراجعة الأخطاء. هل ترى أن اللاعبين هم من يتحملون العبء الأكبر، أم أن المدرب والهيئة الفنية يجب أن يُسألوا أيضًا؟
#
# Guest: هذا سؤال محوري. جواو بيدرو، رغم تألقه بهدف مقصي رائع في الدقيقة 93، أظهر وعيًا رياضيًا نادرًا باعترافه بمسؤولية الفريق collective. لكن المسؤولية لا تُوزّع بالتساوي؛ فالمدرب يُنتَج له الفريق، ويجب أن يُقيّم أداءه بناءً على التكتيك، التحضير، والقدرة على ضبط الأداء تحت الضغط. إذا استمر الأداء السيء، فربما يصبح موقعه معرّضًا للنقد الشديد.
#
# Host: من ناحية تكتيكية، ما هي نقاط الضعف التي كشفها نوتنجهام فورست في تشيلسي؟
#
# Guest: التحليل الفني يُظهر ثغرات واضحة في الدفاع، خاصة في التغطية الجانبية وسرعة الاستجابة للهجمات المرتدة. كما لُوحظ ضعف في بناء اللعب من الخلف، وغياب الوضوح في التوزيع الوظيفي بين خطوط الوسط والهجوم. نوتنجهام فورست استغل هذه الثغرات بذكاء، عبر أهداف مبكرة وتمريرات دقيقة من تايو أونيي وإيجور جيسوس.
#
# Host: ماذا عن الأمل المتبقي في التأهل لدوري الأبطال؟
#
# Guest: الحظوظ أصبحت صعبة جدًا بعد توقف تشيلسي عند 48 نقطة في المركز التاسع. التأهل للمركز الخامس بات شبه مستحيل، لكن المنافسة على المراكز الأوروبية تبقى مشددة حتى نهاية الموسم. المهم أن يُظهر الفريق أداءً استثنائيًا في المباريات المتبقية، مع التركيز على التوازن بين الدفاع والهجوم، وتحقيق الفوز المتتالي.
#
# Host: كيف يتعامل النادي مع الضغط الجماهيري، خاصةً مع اعتراف جواو بيدرو بشعور الفريق بالأسف تجاه الجماهير؟
#
# Guest: التواصل مع الجماهير ضروري. النادي يجب أن يُظهر شفافية في تفسير الأزمة، ويُبرز خطواته الإصلاحية. الدعم الجماهيري، إن وُجّه بذكاء، يمكن أن يُعزز الأداء، لا أن يُثقل اللاعبين. الجماهير تلعب دورًا محوريًا في تحفيز اللاعبين وتعزيز الروح المعنوية.
#
# Host: أخيرًا، ما هي الخطوات المستقبلية التي ترى أنها ضرورية لاستعادة تشيلسي لمستواه؟
#
# Guest: هناك ثلاثة محاور: أولها الدعم الإداري – تخفيف الضغوط على اللاعبين عبر دعم معنوي ومادي. ثانيها التخطيط الاستراتيجي للموسم المقبل، خاصة في الاستثمار في اللاعبين الشباب. وثالثها الاستفادة من التحليل الفني لتحويل الأخطاء إلى فرص تطوير. خطة طويلة الأمد، مدعومة بإدارة فعّالة، هي المفتاح لاستعادة التشيلسي القديم.
#
# Host: شكرًا جزيلًا لك على هذا التحليل الشامل، ونتمنى لتشيلسي والجميع التوفيق.
#
# Guest: شكرًا لك.
#
# ---

# %%
from chat import clipsGeneration_chat_chain
clips = clipsGeneration_chat_chain.invoke({"script": script})

# %%
clips = tojson(clips)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 clips = tojson(clips)
#
# File c:\Users\aliaa\Desktop\genrative ai\online-AI-host\utils.py:5, in tojson(text)
#       3 def tojson (text):
# ----> 5   data = json.loads(text.content)
#       6   return data
#
# AttributeError: 'dict' object has no attribute 'content'

# %%
for key, value in clips.items():
    
    # print(f"{key}\n: {value}\n")
    for v in value:
        for k, val in v.items():
            print(f"{k}\n: {val}\n")
# Out:
# title
# : أزمة تشيلسي هيكلية.. ليس تذبذبًا مؤقتًا
#
# hook
# : هذه الخسارة ليست منعزلة؛ بل هي تكرار لسلسلة من الأداءات غير المستقرة، ما يشير إلى أزمة هيكلية، لا مجرد تذبذب مؤقت.
#
# start_turn
# : 3
#
# end_turn
# : 3
#
# reason
# : عبارة قوية وواضحة تُلخّص جوهر الأزمة بجرأة، وتثير فضول الجمهور لفهم طبيعة هذه الأزمة الهيكلية. مناسبة جدًا لمنصات السوشيال ميديا بسبب صيغتها الصادمة والمباشرة.
#
# viral_score
# : 9
#
# title
# : المسؤولية لا تُوزّع بالتساوي!
#
# hook
# : المسؤولية لا تُوزّع بالتساوي؛ فالمدرب يُنتَج له الفريق، ويجب أن يُقيّم أداءه بناءً على التكتيك، التحضير، والقدرة على ضبط الأداء تحت الضغط.
#
# start_turn
# : 6
#
# end_turn
# : 6
#
# reason
# : بيان جريء يُثير النقاش حول مسؤولية المدرب، ويُقدّم رأيًا تحليليًا متوازنًا لكنه حاسم. يناسب منصات مثل تيك توك حيث يتفاعل الجمهور مع الجدل الرياضي.
#
# viral_score
# : 8
#
# title
# : الهدف المبكر كسر تركيز تشيلسي نفسيًا
#
# hook
# : الهدف المبكر لنوتنجهام فورست كان له تأثير نفسي كبير على لاعبي تشيلسي، إذ أفقد الفريق تركيزه ودفعه إلى اللعب في ملعب الخصم منذ الدقائق الأولى.
#
# start_turn
# : 2
#
# end_turn
# : 2
#
# reason
# : يُبرز تحليلًا نفسيًا نادرًا في التغطية الرياضية، ويُفسّر كيف تُغيّر لحظة واحدة مسار المباراة بالكامل. محتوى جذاب للجمهور الذي يبحث عن أسباب أعمق وراء الخسارة.
#
# viral_score
# : 7
#
# title
# : 3 محاور لإنقاذ تشيلسي من الأزمة
#
# hook
# : هناك ثلاثة محاور: أولها الدعم الإداري – تخفيف الضغوط على اللاعبين عبر دعم معنوي ومادي. ثانيها التخطيط الاستراتيجي للموسم المقبل، خاصة في الاستثمار في اللاعبين الشباب. وثالثها الاستفادة من التحليل الفني لتحويل الأخطاء إلى فرص تطوير.
#
# start_turn
# : 11
#
# end_turn
# : 11
#
# reason
# : خاتمة عملية ومُلهمة، تقدّم حلولًا ملموسة وواضحة. مثالية لـ YouTube Shorts حيث يبحث المشاهدون عن استنتاجات وخطط مستقبلية.
#
# viral_score
# : 8
