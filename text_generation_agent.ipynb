# %%
key_points = {

  "topics": [
    {
      "title": "الأداء المتواضع لتشيلسي في الدوري الإنجليزي",
      "key_points": [
        "خسارة تشيلسي أمام نوتنجهام فورست بنتيجة 3-1",
        "استقبال هدف مبكر عقد مهمة الفريق"
      ],
      "insight": "الأداء غير المستقر لتشيلسي يمكن أن يؤدي إلى فقدان مركز مؤهل لدوري أبطال أوروبا.",
      "discussion_angles": [
        "ما هي أسباب التراجع المستمر في أداء تشيلسي؟",
        "كيف يمكن للنادي مواجهة هذه التحديات؟"
      ]
    },
    {
      "title": "مسؤولية اللاعبين في أخطاء الفريق",
      "key_points": [
        "جواو بيدرو يحمّل اللاعبين المسؤولية",
        "ضرورة مراجعة الأخطاء والعمل على تصحيحها"
      ],
      "insight": "مسؤولية اللاعبين تُظهر حاجة الفريق إلى تحليل ذاتي شامل وتطبيق تغييرات فنية.",
      "discussion_angles": [
        "هل يتحمل المدرب مسؤولية أكبر في هذه الأخطاء؟",
        "كيف يمكن للإدارة دعم اللاعبين؟"
      ]
    },
    {
      "title": "الأمل المتبقي في التأهل لدوري أبطال أوروبا",
      "key_points": [
        "تأهل تشيلسي لدوري أبطال أوروبا أصبح صعبًا",
        "ختصمت حظوظ الفريق بعد توقفه عند النقطة 48 في المركز التاسع"
      ],
      "insight": "رغم صعوبة الحظوظ، يمكن للنادي الاعتماد على أداء قوي في المباريات المتبقية.",
      "discussion_angles": [
        "ما هي الإستراتيجية المثلى لتشيلسي لتحقيق الفوز في المباريات المقبلة؟",
        "هل يمكن لتشيلسي العودة وتخطي المنافسين؟"
      ]
    },
    {
      "title": "أداء نوتنجهام فورست المميز",
      "key_points": [
        "فوز نوتنجهام فورست بنتيجة 3-1 على تشيلسي",
        "أهداف مبكرة وبASSES من تايو أونيي وإيجور جيسوس"
      ],
      "insight": "نوتنجهام فورست أثبت كفاءته في ضرب نقاط ضعف تشيلسي。",
      "discussion_angles": [
        "ما هي نقاط القوة لدى نوتنجهام فورست؟",
        "كيف يمكن لتشيلسي استخلاص الدروس من هذه الخسارة؟"
      ]
    },
    {
      "title": "تأثير الضغط الجماهيري على اللاعبين",
      "key_points": [
        "جواو بيدرو يعترف بشعور الفريق بالأسف تجاه الجماهير",
        "تعهد اللاعبين بمراجعة الأخطاء والعمل على تصحيحها"
      ],
      "insight": "الدعم الجماهيري مع ضرورة تحمل اللاعبين للمسؤولية يمكن أن يعزز الأداء。",
      "discussion_angles": [
        "كيف يمكن للنادي تحسين التواصل مع الجماهير؟",
        "ما هو دور الجماهير في دعم الفريق؟"
      ]
    },
    {
      "title": "دور المدرب في أزمة تشيلسي",
      "key_points": [
        "جواو بيدرو يؤكد أن المسؤولية تقع على اللاعبين",
        " belum ada بحاجة إلى حل سريع للمشاكل"
      ],
      "insight": "موقف المدرب قد يكون معرضاً للنقد إذا استمر الأداء السيء.",
      "discussion_angles": [
        "ما هي الدور التي يجب أن يلعبها المدرب في مواجهة هذه الأزمات؟",
        "هلneeds change in the coaching staff؟"
      ]
    },
    {
      "title": "تألق جواو بيدرو رغم الخسارة",
      "key_points": [
        "مارضة جواو بيدرو للهدف الوحيد لتشيلسي بمقصية رائعة في الدقيقة 93",
        " SPEAKING اعترافه بتحمل المسؤولية"
      ],
      "insight": "الهداف انعكس إيجابياً على روحه الرياضية رغم الخسارة.",
      "discussion_angles": [
        "كيف يمكن لجواو بيدرو البناء على هذا الأداء؟",
        "ما هي توقعات الجماهير منه في المباريات المقبلة؟"
      ]
    },
    {
      "title": "المنافسة على المراكز المؤهلة لدوري أبطال أوروبا",
      "key_points": [
        " antioxid تشيلسي لحصد المركز الخامس أصبح شبه مستحيل",
        " COMPLEXITY في الترتيبات النهائية للدوري الإنجليزي"
      ],
      "insight": "المنافسة على المراكز الأوروبية تبقى مشددة حتى نهاية الموسم.",
      "discussion_angles": [
        "ما هي حظوظ الفرق الأخرى في تحقيق التأهل؟",
        "كيف يمكن لتشيلسي استعادة موقعه؟"
      ]
    },
    {
      "title": "تأثير الأهداف المبكرة على سير المباراة",
      "key_points": [
        "رسم النتيجة المبكرة لنوتنجهام فورست أثرت سلباً على تشيلسي",
        "اضطرار تشيلسي للم fabs بتحقيق التعويض"
      ],
      "insight": "الأهداف المبكرة تؤثر بشكل كبير على ديناميكية المباراة.",
      "discussion_angles": [
        "كيف يمكن لتشيلسي تعزيز تحمله للأهداف المبكرة؟",
        "ما هي استراتيجيات الإعداد النفسي للفرق؟"
      ]
    },
    {
      "title": "التحليل الفني للخسارة",
      "key_points": [
        "(locations الفريق في تلقي الأهداف",
        "الثغرات الدفاعية والهجومية"
      ],
      "insight": "الخسارة أمام نوتنجهام فورست كشفت عن نقاط ضعف واضحة في تكتيكات تشيلسي.",
      "discussion_angles": [
        "ما هي الطرق المثلى لتعزيز الدفاع والهجوم؟",
        "كيف يمكن للفريق الاستفادة من التحليل الفني؟"
      ]
    },
    {
      "title": "المباريات المحتملة القادمة لتشيلسي",
      "key_points": [
        "جداول المباريات المتبقية لتشيلسي",
        "ما هو مطلوب لتحقيق الفوز"
      ],
      "insight": "جدول المباريات يتطلب أداءً استثنائياً لتحقيق الفوز في جميع المباريات المتبقية.",
      "discussion_angles": [
        "ما هي التحديات المحددة في هذه المباريات؟",
        "كيف يمكن لتشيلسي الاستعداد لهذه المواجهات؟"
      ]
    },
    {
      "title": "الدعم الإداري ودوره في تحقيق الاستقرار",
      "key_points": [
        "-role الإدارة في تخفيف الضغوط على اللاعبين",
        "الدعم المادي والمعنوي"
      ],
      "insight": "الإدارة يمكن أن تلعب دوراً مهماً في استعادة ثقة اللاعبين وتعزيز أدائهم.",
      "discussion_angles": [
        "ما هي الإجراءات المتخذة من قبل الإدارة؟",
        "كيف يمكن تقييم نجاح هذه الإجراءات؟"
      ]
    },
    {
      "title": "الاستراتيجيات التطويرية للنادي",
      "key_points": [
        "التخطيط للموسم المقبل",
        "الاستثمار في اللاعبين الشباب"
      ],
      "insight": "خطة تطوير طويلة الأمد يمكن أن تساعد تشيلسي في الاستعادة سريعاً.",
      "discussion_angles": [
        "ما هي الخطوات المستقبلية للنادي؟",
        "كيف يمكن تطوير الفريق بشكل مستدام؟"
      ]
    },
    {
      "title": "التأثير الإعلامي على الفريق",
      "key_points": [
        "التغطية الإعلامية للخسارة",
        " النقد والإشادة"
      ],
      "insight": "التغطية الإعلامية قد تؤثر إما بالإيجاب أو السلب على أداء اللاعبين.",
      "discussion_angles": [
        "ما هو تأثير الصحافة على الفريق؟",
        "كيف يمكن إدارة هذا التأثير بشكل فعال؟"
      ]
    },
    {
      "title": "الدور consultar الجماهير في دعم الفريق",
      "key_points": [
        "ال心情 الجماهيرية بعد الخسارة",
        "استمرار الدعم الجماهيري"
      ],
      "insight": "الجماهير تلعب دوراً مهماً في تحفيز اللاعبين وتعزيز الروح المعنوية.",
      "discussion_angles": [
        "كيف يمكن للجماهير مواصلة دعم الفريق؟",
        "ما هو دور الجماهير في تحقيق النجاح؟"
      ]
    }
  ]

}

# %%
from chat import textGeneration_chat_chain 
from utils import tojson 
from utils import print_script 
script = textGeneration_chat_chain.invoke({
    "key_points": key_points,
    "tone": "quite",
    "speech_speed": 1,
    "video_duration": 900
})

# %%
from audio import text_to_speech
text_to_speech(script, "output.mp3")
# Out:
# <coroutine object text_to_speech at 0x00000253E3DAD6C0>

# %%
#  Munsit test - saudii (male)
result = await text_to_speech(
    text="مرحباً",
    provider="munsit",
    language="ar",
    dialect="saudi",
    gender="male",
    style="professional",
    speed=1.0
)

print("="*50)
print("📊 اختبار Munsit (سعودي - رجل)")
print("="*50)
print(f"✅ Success: {result.get('success')}")
print(f"🎙️ Provider: {result.get('provider')}")
print(f"🗣️ Voice: {result.get('voice')}")
print(f"⏱️ Duration: {result.get('duration', 0):.2f} seconds")
print(f"🔗 Audio URL: {result.get('audio_url')}")
print("="*50)

if result.get('audio_url'):
    import requests
    from IPython.display import Audio, display
    response = requests.get(result['audio_url'])
    display(Audio(response.content))
# Out:
# ...
# Generating speech...
#    Text: مرحباً...
#    Language: ar | Provider: gtts
#    Dialect: fusha | Gender: male | Style: professional | Speed: 1.0
# ...
# Using gTTS
# ...
# 📊 اختبار Munsit (سعودي - رجل)
# ...
# ✅ Success: True
# 🎙️ Provider: gtts
# 🗣️ Voice: Arabic (Fusha) (gTTS)
# ⏱️ Duration: 1.15 seconds
# 🔗 Audio URL: https://res.cloudinary.com/duxc6oeju/video/upload/v1778851603/podcast_audio/uqmbtyo34b8n5pftpt1q.mp3
# ...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
script = tojson(script)
print_script(script)
# Out:
# 1
# Page 1:
# Host: مرحباً بكم في هذا اللقاء الخاص الذي يتناول أداء نادي تشيلسي في الدوري الإنجليزي الممتاز، بعد أحدث مواجهاته الصعبة أمام نوتنجهام فورست التي انتهت بخسارة مُرّة بنتيجة 3-1. معنا اليوم ضيف خبير في شؤون الكرة الإنجليزية، لنتناول الأسباب، التداعيات، والمسارات الممكنة لاستعادة الثقة. مرحباً بك!
#
# Guest: شكرًا لك، سعيد بالمشاركة.
#
# Host: دعنا نبدأ من الخسارة نفسها: كيف تفسّر تراجع تشيلسي إلى هذا الحد، خاصةً بعد أن استقبل هدفًا مبكرًا عقّد المهمة فور انطلاق المباراة؟
#
# Guest: بالفعل، الهدف المبكر لنوتنجهام فورست كان له تأثير نفسي كبير على لاعبي تشيلسي، إذ أفقد الفريق تركيزه ودفعه إلى اللعب في ملعب الخصم منذ الدقائق الأولى. لكن الأهم من ذلك أن هذه الخسارة ليست منعزلة؛ بل هي تكرار لسلسلة من الأداءات غير المستقرة، ما يشير إلى أزمة هيكلية، لا مجرد تذبذب مؤقت. الأداء غير المستقر قد يؤدي إلى فقدان مركز مؤهل لدوري أبطال أوروبا، وهو ما يُقلق الجماهير والمسؤولين على حد سواء.
#
# ...

# %%
from chat import clipsGeneration_chat_chain
clips = clipsGeneration_chat_chain.invoke({"script": script})

# %%
clips = tojson(clips)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 clips = tojson(clips)
#
# File c:\Users\aliaa\Desktop\genrative ai\online-AI-host\utils.py:5, in tojson(text)
#       3 def tojson (text):
# ----> 5   data = json.loads(text.content)
#       6   return data
#
# AttributeError: 'dict' object has no attribute 'content'

# %%
for key, value in clips.items():
    
    # print(f"{key}\n: {value}\n")
    for v in value:
        for k, val in v.items():
            print(f"{k}\n: {val}\n")
# Out:
# title
# : أزمة تشيلسي هيكلية.. ليس تذبذبًا مؤقتًا
#
# hook
# : هذه الخسارة ليست منعزلة؛ بل هي تكرار لسلسلة من الأداءات غير المستقرة، ما يشير إلى أزمة هيكلية، لا مجرد تذبذب مؤقت.
#
# start_turn
# : 3
#
# end_turn
# : 3
#
# reason
# : عبارة قوية وواضحة تُلخّص جوهر الأزمة بجرأة، وتثير فضول الجمهور لفهم طبيعة هذه الأزمة الهيكلية. مناسبة جدًا لمنصات السوشيال ميديا بسبب صيغتها الصادمة والمباشرة.
#
# viral_score
# : 9
#
# title
# : المسؤولية لا تُوزّع بالتساوي!
#
# hook
# : المسؤولية لا تُوزّع بالتساوي؛ فالمدرب يُنتَج له الفريق، ويجب أن يُقيّم أداءه بناءً على التكتيك، التحضير، والقدرة على ضبط الأداء تحت الضغط.
#
# start_turn
# : 6
#
# end_turn
# : 6
#
# reason
# : بيان جريء يُثير النقاش حول مسؤولية المدرب، ويُقدّم رأيًا تحليليًا متوازنًا لكنه حاسم. يناسب منصات مثل تيك توك حيث يتفاعل الجمهور مع الجدل الرياضي.
#
# viral_score
# : 8
#
# title
# : الهدف المبكر كسر تركيز تشيلسي نفسيًا
#
# hook
# ...
